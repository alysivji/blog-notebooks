# %%
from __future__ import print_function
from IPython.html.widgets import interact, interactive, fixed
from IPython.html import widgets
# Out:
# /Users/alysivji/anaconda/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df = df.cumsum()

# %%
df.plot()

# %%
import seaborn as sns

# %%
df.plot()

# %%
col = ['A', 'B', 'C', 'D']
@interact
def df_plot(x=col):
    df[x].plot()
