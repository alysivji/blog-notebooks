# %%
# standard library
from collections import namedtuple
import os

# pydata
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# bson-numpy libraries
import numpy as np
from bson import CodecOptions
from bson.raw_bson import RawBSONDocument
from pymongo import MongoClient
import bsonnumpy

# other libraries
import maya

# %%
# get mongodb params (using configparser)
mlab_uri = os.environ['MLAB_URI']
mlab_collection = os.environ['MLAB_COLLECTION']

# %%
codec_options=CodecOptions(document_class=RawBSONDocument)
client = MongoClient(mlab_uri)
db = client.get_default_database()
collection = db.get_collection(
    mlab_collection,
    codec_options=codec_options
)

# %% [markdown]
# https://docs.scipy.org/doc/numpy/reference/generated/numpy.dtype.html#numpy.dtype

# %%
# we only pull the fields defined here
dtype = np.dtype(
    [   ('id_str', 'S20'),
        ('full_text', 'S400'),
        ('created_at', 'S64'),
        ('retweeted', 'b'),
    ]
)

# %%
ndarray = bsonnumpy.sequence_to_ndarray(
    (doc.raw for doc in collection.find()), 
    dtype, 
    collection.count(),
)

# %%
print(ndarray)
# Out:
# [ (b'942143177330487296', b'Still. API keys in ipython notebooks! Yikes', b'Sat Dec 16 21:23:32 +0000 2017', 0)
#  (b'942142988574175232', b'Fixing up a project I worked on in April 2016. Good job me for documenting sorta well', b'Sat Dec 16 21:22:47 +0000 2017', 0)
#  (b'942133480699260929', b'https://t.co/6Ubtx6S1O8\n#bookmark', b'Sat Dec 16 20:45:00 +0000 2017', 0)
#  ...,
#  (b'942148741343186945', b'Was also logging to AWS CloudWatch. Best practices sorta', b'Sat Dec 16 21:45:38 +0000 2017', 0)
#  (b'942199189223673857', b'Got my local dev environment all set up. @droneio builds are also passing. Can finally start working on the business logic! #dockercompose #devops', b'Sun Dec 17 01:06:06 +0000 2017', 0)
#  (b'942281643926093824', b'RT @crossphd: Pushpin \xe2\x80\x94 An Open Source Library That Turns REST APIs into Realtime APIs - An intro to evented APIs and how to build them wit\xe2\x80\xa6', b'Sun Dec 17 06:33:45 +0000 2017', 1)]

# %%
tweets = pd.DataFrame(ndarray)

# %%
tweets['id_str'] = tweets['id_str'].str.decode('utf-8')
tweets['full_text'] = tweets['full_text'].str.decode('utf-8')
tweets['created_at'] = tweets['created_at'].str.decode('utf-8')

# %%
tweets.head()
# Out:
#                id_str                                          full_text  \
# 0  942143177330487296        Still. API keys in ipython notebooks! Yikes
# 1  942142988574175232  Fixing up a project I worked on in April 2016....
# 2  942133480699260929                 https://t.co/6Ubtx6S1O8\n#bookmark
# 3  942129673416343552  RT @dbader_org: A list of things that might be...
# 4  942128018516037633  VSCode November release \nhttps://t.co/U4nzPLE8QI
#
#                        created_at  retweeted
# 0  Sat Dec 16 21:23:32 +0000 2017          0
# 1  Sat Dec 16 21:22:47 +0000 2017          0
# 2  Sat Dec 16 20:45:00 +0000 2017          0
# 3  Sat Dec 16 20:29:52 +0000 2017          1
# 4  Sat Dec 16 20:23:18 +0000 2017          0

# %%
tweets['retweeted'].value_counts()
# Out:
# 0    1774
# 1     795
# Name: retweeted, dtype: int64

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2569 entries, 0 to 2568
# Data columns (total 4 columns):
# id_str        2569 non-null object
# full_text     2569 non-null object
# created_at    2569 non-null object
# retweeted     2569 non-null int8
# dtypes: int8(1), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# ### Parse datetime and convert to correct timezone

# %%
# create helper function (which we can probably move into sivtools)

ConvertTZArgs = namedtuple("ConvertTZArgs", ["dt_col", "to_timezone"])

def convert_timezone(row, *args):
    # get datetime
    dt_col = args[0].dt_col
    to_timezone = args[0].to_timezone
    dt = row[dt_col]
    
    dt = maya.parse(dt).datetime(to_timezone=to_timezone)
    return dt

# %%
tweets['created_at'] = tweets.apply(
    convert_timezone,
    axis=1, 
    args=(ConvertTZArgs('created_at', 'US/Central'),)
)

# %%
tweets['chars'] = tweets['full_text'].str.len()

# %%
tweets.head()
# Out:
#                id_str                                          full_text  \
# 0  942143177330487296        Still. API keys in ipython notebooks! Yikes
# 1  942142988574175232  Fixing up a project I worked on in April 2016....
# 2  942133480699260929                 https://t.co/6Ubtx6S1O8\n#bookmark
# 3  942129673416343552  RT @dbader_org: A list of things that might be...
# 4  942128018516037633  VSCode November release \nhttps://t.co/U4nzPLE8QI
#
#                  created_at  retweeted  chars
# 0 2017-12-16 15:23:32-06:00          0     43
# 1 2017-12-16 15:22:47-06:00          0     85
# 2 2017-12-16 14:45:00-06:00          0     33
# 3 2017-12-16 14:29:52-06:00          1    140
# 4 2017-12-16 14:23:18-06:00          0     48

# %%
tweets.tail()
# Out:
#                   id_str                                          full_text  \
# 2564  284018476102848512  3D printers are bringing us into the age of St...
# 2565  284008146480009216                  Starting up a new public account.
# 2566  942148741343186945  Was also logging to AWS CloudWatch. Best pract...
# 2567  942199189223673857  Got my local dev environment all set up. @dron...
# 2568  942281643926093824  RT @crossphd: Pushpin — An Open Source Library...
#
#                     created_at  retweeted  chars
# 2564 2012-12-26 13:30:56-06:00          0    114
# 2565 2012-12-26 12:49:53-06:00          0     33
# 2566 2017-12-16 15:45:38-06:00          0     56
# 2567 2017-12-16 19:06:06-06:00          0    146
# 2568 2017-12-17 00:33:45-06:00          1    140

# %%
tweets.describe(include='all')
# Out:
#                     id_str                                          full_text  \
# count                 2569                                               2569
# unique                2569                                               2562
# top     865715029621874688  RT @PythonQnA: Proper way to declare custom ex...
# freq                     1                                                  2
# mean                   NaN                                                NaN
# std                    NaN                                                NaN
# min                    NaN                                                NaN
# 25%                    NaN                                                NaN
# 50%                    NaN                                                NaN
# 75%                    NaN                                                NaN
# max                    NaN                                                NaN
#
#                        created_at    retweeted        chars
# count                        2569  2569.000000  2569.000000
# unique                       2569          NaN          NaN
# top     2016-12-10 00:05:07-06:00          NaN          NaN
# freq                            1          NaN          NaN
# mean                          NaN     0.309459   103.272480
# std                           NaN     0.462361    33.810651
# min                           NaN     0.000000     2.000000
# 25%                           NaN     0.000000    79.000000
# 50%                           NaN     0.000000   107.000000
# 75%                           NaN     1.000000   135.000000
# max                           NaN     1.000000   231.000000

# %% [markdown]
# ---

# %% [markdown]
# ## Get original and retweeted separately
#
# How are they different?

# %% [markdown]
# ### Original

# %%
# we only pull the fields defined here
dtype_original = np.dtype(
    [   ('id_str', 'S20'),
        ('full_text', 'S400'),
        ('created_at', 'S64'),
        ('retweeted', 'b'),
    ]
)

# %%
ndarray_original = bsonnumpy.sequence_to_ndarray(
    (doc.raw for doc in collection.find({"retweeted_status": {"$exists": False}})), 
    dtype_original, 
    collection.count(),
)

# %%
print(ndarray_original)
# Out:
# [ (b'942143177330487296', b'Still. API keys in ipython notebooks! Yikes', b'Sat Dec 16 21:23:32 +0000 2017', 0)
#  (b'942142988574175232', b'Fixing up a project I worked on in April 2016. Good job me for documenting sorta well', b'Sat Dec 16 21:22:47 +0000 2017', 0)
#  (b'942133480699260929', b'https://t.co/6Ubtx6S1O8\n#bookmark', b'Sat Dec 16 20:45:00 +0000 2017', 0)
#  ...,
#  (b'284008146480009216', b'Starting up a new public account.', b'Wed Dec 26 18:49:53 +0000 2012', 0)
#  (b'942148741343186945', b'Was also logging to AWS CloudWatch. Best practices sorta', b'Sat Dec 16 21:45:38 +0000 2017', 0)
#  (b'942199189223673857', b'Got my local dev environment all set up. @droneio builds are also passing. Can finally start working on the business logic! #dockercompose #devops', b'Sun Dec 17 01:06:06 +0000 2017', 0)]

# %%
tweets_original = pd.DataFrame(ndarray_original)

# %%
tweets_original['id_str'] = tweets_original['id_str'].str.decode('utf-8')
tweets_original['full_text'] = tweets_original['full_text'].str.decode('utf-8')
tweets_original['created_at'] = tweets_original['created_at'].str.decode('utf-8')

# %%
tweets_original.head()
# Out:
#                id_str                                          full_text  \
# 0  942143177330487296        Still. API keys in ipython notebooks! Yikes
# 1  942142988574175232  Fixing up a project I worked on in April 2016....
# 2  942133480699260929                 https://t.co/6Ubtx6S1O8\n#bookmark
# 3  942128018516037633  VSCode November release \nhttps://t.co/U4nzPLE8QI
# 4  942124280183250954  @TooManyNickLees It does for this project I'm ...
#
#                        created_at  retweeted
# 0  Sat Dec 16 21:23:32 +0000 2017          0
# 1  Sat Dec 16 21:22:47 +0000 2017          0
# 2  Sat Dec 16 20:45:00 +0000 2017          0
# 3  Sat Dec 16 20:23:18 +0000 2017          0
# 4  Sat Dec 16 20:08:26 +0000 2017          0

# %%
tweets_original['retweeted'].value_counts()
# Out:
# 0    1571
# Name: retweeted, dtype: int64

# %%
tweets_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 4 columns):
# id_str        1571 non-null object
# full_text     1571 non-null object
# created_at    1571 non-null object
# retweeted     1571 non-null int8
# dtypes: int8(1), object(3)
# memory usage: 38.4+ KB

# %% [markdown]
# ---

# %% [markdown]
# ### Retweeted

# %%
# we only pull the fields defined here
dtype_rt = np.dtype(
    [   ('id_str', 'S20'),
        ('retweeted_status', np.dtype([('full_text', 'S400')])),
        ('created_at', 'S64'),
        ('retweeted', 'b'),
    ]
)

# %%
ndarray_rt = bsonnumpy.sequence_to_ndarray(
    (doc.raw for doc in collection.find({"retweeted_status": {"$exists": True}})), 
    dtype_rt, 
    collection.count(),
)

# %%
tweets_rt = pd.DataFrame(ndarray_rt)

# %%
tweets_rt['id_str'] = tweets_rt['id_str'].str.decode('utf-8')
tweets_rt['full_text'] = tweets_rt['retweeted_status'].map(lambda value: value[0].decode('utf-8'))
tweets_rt['created_at'] = tweets_rt['created_at'].str.decode('utf-8')

# %%
tweets_rt.head()
# Out:
#                id_str                                   retweeted_status  \
# 0  942129673416343552  (b'A list of things that might be useful when ...
# 1  942124389352566785  (b'OUT: import pdb; pdb.set_trace()\nIN: break...
# 2  942073565154893824  (b'Great news, Guido has pronounced dicts to r...
# 3  942028275249041408  (b'First ever PyCon happening in Pakistan http...
# 4  941899375424524289  (b'#python news:  \xf0\x9f\x98\x80 @gvanrossum...
#
#                        created_at  retweeted  \
# 0  Sat Dec 16 20:29:52 +0000 2017          1
# 1  Sat Dec 16 20:08:52 +0000 2017          1
# 2  Sat Dec 16 16:46:55 +0000 2017          1
# 3  Sat Dec 16 13:46:57 +0000 2017          1
# 4  Sat Dec 16 05:14:45 +0000 2017          1
#
#                                            full_text
# 0  A list of things that might be useful when ans...
# 1  OUT: import pdb; pdb.set_trace()\nIN: breakpoi...
# 2  Great news, Guido has pronounced dicts to reta...
# 3  First ever PyCon happening in Pakistan https:/...
# 4  #python news:  😀 @gvanrossum just pronounced t...

# %%
tweets_rt['retweeted'].value_counts()
# Out:
# 1    795
# 0    203
# Name: retweeted, dtype: int64

# %%
tweets_original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1571 entries, 0 to 1570
# Data columns (total 4 columns):
# id_str        1571 non-null object
# full_text     1571 non-null object
# created_at    1571 non-null object
# retweeted     1571 non-null int8
# dtypes: int8(1), object(3)
# memory usage: 38.4+ KB

# %%
tweets_rt[tweets_rt['retweeted'] == 0]
# Out:
#                  id_str                                   retweeted_status  \
# 794  838811334296862721  (b'#TruvenHealth and #IBMWatson announced our ...
# 795  838784428520407040  (b'Happy Birthday Toronto! #OTD in 1834 the to...
# 796  838784352343379968  (b'Is an MBA helpful for people who want to wo...
# 797  838696318340063232  (b'Challenges of using Twitter as a data sourc...
# 798  838626694273634305  (b'Getting Started with #DeepLearning in #Pyth...
# 799  838619112326709248  (b'A step by step guide for getting Python 3.6...
# 800  838618194499751938  (b'Introducing #IBMQ quantum systems, building...
# 801  838618092985008128  (b'IBM is launching IBM Q \xe2\x80\x94 an effo...
# 802  838599397789298688  (b'10 Scifi\xc2\xa0Curse Words for All Occasio...
# 803  838027902302228480  (b'A mythical full stack developer https://t.c...
# 804  837889733208465408  (b'New @TensorFlow course from Stanford by @ch...
# 805  837708289160921089  (b'Google and IBM: We Want #ArtificialIntellig...
# 806  837641482270044160  (b'Ah this is great: "A curated list of shell ...
# 807  837424204240797697  (b'Set conda environment within sha-bang? http...
# 808  837409793421819904  (b'How does one create a business plan? https:...
# 809  837355421862100992  (b'What\xe2\x80\x99s happening in your neighbo...
# 810  837348190278062081  (b'Snap Co-Founders Score $3 Billion Gain on F...
# 811  837321317921787904  (b'President Trump lists five-point plan for A...
# 812  836027899429937160  (b'\xe2\x80\x9cWrite code that\xe2\x80\x99s ea...
# 813  835646320035651584  (b'Jupyter Notebook Best Practices for #DataSc...
# 814  835564550133022720  (b'Haha, this is awesome \xf0\x9f\x91\x8f "The...
# 815  835514845617344513          (b'Top-10 #OHN https://t.co/z7HYGNN3vK',)
# 816  835310154895745025  (b'Machine learning is the new \xe2\x80\x9cpla...
# 817  835242797103996928  (b'Tom Boonen will be using a special edition ...
# 818  835237766296395776  (b"Get the brand new Microservice Architecture...
# 819  835208492248141828  (b'Prophet: a scalable, fast forecasting proce...
# 820  834117157898313728  (b'Suddenly, Dubai Aims to Become First Blockc...
# 821  833889252601634818  (b'It\xe2\x80\x99s Proven That You\xe2\x80\x99...
# 822  833817379427721216  (b'Very useful for anyone using tables to pres...
# 823  832939593192316928  (b'Study Website Performance Optimization with...
# ..                  ...                                                ...
# 967  502244827241914370  (b'.@Jawbone takes a look closer at how people...
# 968  496644826377773056  (b'Data graphics in #rstats using #ggplot2. I ...
# 969  491326026077585409  (b"The @NewYorker opened their archive. Here's...
# 970  489420668409094145  (b'Introducing RcppParallel for high-level C++...
# 971  488012489993379840  (b'5,000 days of #ISS \xe2\x80\x93 82 countrie...
# 972  481090859623280640  (b'How is Healthcare Leveraging the Cloud? htt...
# 973  473567124636844032  (b'Meet the 26 brightest minds in #healthIT ac...
# 974  473527223203291136  (b'Best Practices in #Data &amp; #Analytics: J...
# 975  464748748560941056  (b'Let\xe2\x80\x99s Make a Bubble Map http://t...
# 976  458578935245467648  (b"I wish this didn't seem true...sadly it doe...
# 977  451085955315683328  (b'as long as people are looking for someone t...
# 978  448648322858115073  (b'Congrats! RT @bolsish: Arrested development...
# 979  444251175735394304  (b'FULL STORY: @NMHnews, @Cadence_Health signe...
# 980  442882582145798144  (b'Venture funds see growth in health care sta...
# 981  441679591522840576  (b'NASA analysis of airborne radar data may be...
# 982  439040522569519105  (b'@KBDeSalvo: In three years, data will be fr...
# 983  437686535513583616  (b'RT to welcome @jasoncollins34 to Brooklyn! ...
# 984  431292663527403520  (b'you are invited to witness chicago health t...
# 985  413081986975019009  (b'Everything that happened in 2013 in one ima...
# 986  411607131880562688  (b'This product, called a Gene-Radar, can diag...
# 987  410549506858426368  (b"It's National Lager Day! How are you celebr...
# 988  399238086107725824  (b'5 fun apps to help sharpen your memory -- i...
# 989  392639548359856129  (b'Between July 13 (4.5k new jobs) and Sept (6...
# 990  390488811693555712  (b'Reducing Hospital Admissions from the Emerg...
# 991  390286601164578816  (b'Overcoming Fragmentation in Health Care #Fu...
# 992  389818040004931584  (b'@MikeBloomberg your New Years pledge was to...
# 993  387601590846095360  (b'.@KinectWindows has improved patient experi...
# 994  385050974697435136  (b'[MG] What the Government Shutdown Means for...
# 995  382896970093715456  (b'We are giving away a copy of #FIFA14 for PS...
# 996  294806759556661249  (b"Since so many seem to think the media manip...
#
#                          created_at  retweeted  \
# 794  Mon Mar 06 17:59:41 +0000 2017          0
# 795  Mon Mar 06 16:12:46 +0000 2017          0
# 796  Mon Mar 06 16:12:28 +0000 2017          0
# 797  Mon Mar 06 10:22:39 +0000 2017          0
# 798  Mon Mar 06 05:45:59 +0000 2017          0
# 799  Mon Mar 06 05:15:51 +0000 2017          0
# 800  Mon Mar 06 05:12:12 +0000 2017          0
# 801  Mon Mar 06 05:11:48 +0000 2017          0
# 802  Mon Mar 06 03:57:31 +0000 2017          0
# 803  Sat Mar 04 14:06:36 +0000 2017          0
# 804  Sat Mar 04 04:57:34 +0000 2017          0
# 805  Fri Mar 03 16:56:34 +0000 2017          0
# 806  Fri Mar 03 12:31:06 +0000 2017          0
# 807  Thu Mar 02 22:07:43 +0000 2017          0
# 808  Thu Mar 02 21:10:27 +0000 2017          0
# 809  Thu Mar 02 17:34:24 +0000 2017          0
# 810  Thu Mar 02 17:05:40 +0000 2017          0
# 811  Thu Mar 02 15:18:53 +0000 2017          0
# 812  Mon Feb 27 01:39:18 +0000 2017          0
# 813  Sun Feb 26 00:23:02 +0000 2017          0
# 814  Sat Feb 25 18:58:07 +0000 2017          0
# 815  Sat Feb 25 15:40:36 +0000 2017          0
# 816  Sat Feb 25 02:07:14 +0000 2017          0
# 817  Fri Feb 24 21:39:35 +0000 2017          0
# 818  Fri Feb 24 21:19:36 +0000 2017          0
# 819  Fri Feb 24 19:23:16 +0000 2017          0
# 820  Tue Feb 21 19:06:42 +0000 2017          0
# 821  Tue Feb 21 04:01:05 +0000 2017          0
# 822  Mon Feb 20 23:15:29 +0000 2017          0
# 823  Sat Feb 18 13:07:28 +0000 2017          0
# ..                              ...        ...
# 967  Thu Aug 21 00:04:32 +0000 2014          0
# 968  Tue Aug 05 13:12:08 +0000 2014          0
# 969  Mon Jul 21 20:57:07 +0000 2014          0
# 970  Wed Jul 16 14:45:55 +0000 2014          0
# 971  Sat Jul 12 17:30:19 +0000 2014          0
# 972  Mon Jun 23 15:06:13 +0000 2014          0
# 973  Mon Jun 02 20:49:35 +0000 2014          0
# 974  Mon Jun 02 18:11:02 +0000 2014          0
# 975  Fri May 09 12:48:30 +0000 2014          0
# 976  Tue Apr 22 12:11:52 +0000 2014          0
# 977  Tue Apr 01 19:57:27 +0000 2014          0
# 978  Wed Mar 26 02:31:10 +0000 2014          0
# 979  Thu Mar 13 23:18:28 +0000 2014          0
# 980  Mon Mar 10 04:40:10 +0000 2014          0
# 981  Thu Mar 06 20:59:55 +0000 2014          0
# 982  Thu Feb 27 14:13:12 +0000 2014          0
# 983  Sun Feb 23 20:32:56 +0000 2014          0
# 984  Thu Feb 06 05:05:58 +0000 2014          0
# 985  Tue Dec 17 23:03:15 +0000 2013          0
# 986  Fri Dec 13 21:22:42 +0000 2013          0
# 987  Tue Dec 10 23:20:04 +0000 2013          0
# 988  Sat Nov 09 18:12:31 +0000 2013          0
# 989  Tue Oct 22 13:12:17 +0000 2013          0
# 990  Wed Oct 16 14:46:02 +0000 2013          0
# 991  Wed Oct 16 01:22:31 +0000 2013          0
# 992  Mon Oct 14 18:20:37 +0000 2013          0
# 993  Tue Oct 08 15:33:15 +0000 2013          0
# 994  Tue Oct 01 14:38:00 +0000 2013          0
# 995  Wed Sep 25 15:58:46 +0000 2013          0
# 996  Fri Jan 25 13:59:43 +0000 2013          0
#
#                                              full_text
# 794  #TruvenHealth and #IBMWatson announced our 100...
# 795  Happy Birthday Toronto! #OTD in 1834 the town ...
# 796  Is an MBA helpful for people who want to work ...
# 797  Challenges of using Twitter as a data source: ...
# 798  Getting Started with #DeepLearning in #Python:...
# 799  A step by step guide for getting Python 3.6 &a...
# 800  Introducing #IBMQ quantum systems, building th...
# 801  IBM is launching IBM Q — an effort to turn its...
# 802  10 Scifi Curse Words for All Occasions https:/...
# 803  A mythical full stack developer https://t.co/K...
# 804  New @TensorFlow course from Stanford by @chipr...
# 805  Google and IBM: We Want #ArtificialIntelligenc...
# 806  Ah this is great: "A curated list of shell com...
# 807  Set conda environment within sha-bang? https:/...
# 808  How does one create a business plan? https://t...
# 809  What’s happening in your neighborhood? Use #50...
# 810  Snap Co-Founders Score $3 Billion Gain on Firs...
# 811  President Trump lists five-point plan for ACA ...
# 812  “Write code that’s easy to delete, not easy to...
# 813  Jupyter Notebook Best Practices for #DataScien...
# 814  Haha, this is awesome 👏 "The Zen of Python" il...
# 815                Top-10 #OHN https://t.co/z7HYGNN3vK
# 816  Machine learning is the new “plastics” and fou...
# 817  Tom Boonen will be using a special edition Spe...
# 818  Get the brand new Microservice Architecture O'...
# 819  Prophet: a scalable, fast forecasting procedur...
# 820  Suddenly, Dubai Aims to Become First Blockchai...
# 821  It’s Proven That You’d Be More Productive If Y...
# 822  Very useful for anyone using tables to present...
# 823  Study Website Performance Optimization with @i...
# ..                                                 ...
# 967  .@Jawbone takes a look closer at how people sl...
# 968  Data graphics in #rstats using #ggplot2. I bet...
# 969  The @NewYorker opened their archive. Here's wh...
# 970  Introducing RcppParallel for high-level C++ pa...
# 971  5,000 days of #ISS – 82 countries have contrib...
# 972  How is Healthcare Leveraging the Cloud? http:/...
# 973  Meet the 26 brightest minds in #healthIT accor...
# 974  Best Practices in #Data &amp; #Analytics: Join...
# 975     Let’s Make a Bubble Map http://t.co/mLisdC2uoI
# 976  I wish this didn't seem true...sadly it does.....
# 977  as long as people are looking for someone to b...
# 978  Congrats! RT @bolsish: Arrested development tr...
# 979  FULL STORY: @NMHnews, @Cadence_Health signed l...
# 980  Venture funds see growth in health care start-...
# 981  NASA analysis of airborne radar data may be ab...
# 982  @KBDeSalvo: In three years, data will be free ...
# 983  RT to welcome @jasoncollins34 to Brooklyn! #Ne...
# 984  you are invited to witness chicago health tech...
# 985  Everything that happened in 2013 in one image ...
# 986  This product, called a Gene-Radar, can diagnos...
# 987  It's National Lager Day! How are you celebrati...
# 988  5 fun apps to help sharpen your memory -- incl...
# 989  Between July 13 (4.5k new jobs) and Sept (6.8k...
# 990  Reducing Hospital Admissions from the Emergenc...
# 991  Overcoming Fragmentation in Health Care #Futur...
# 992  @MikeBloomberg your New Years pledge was to le...
# 993  .@KinectWindows has improved patient experienc...
# 994  [MG] What the Government Shutdown Means for #H...
# 995  We are giving away a copy of #FIFA14 for PS3! ...
# 996  Since so many seem to think the media manipula...
#
# [203 rows x 5 columns]

# %% [markdown]
# ## Looks like these are RTs. The better flag is if they have a retweeted_status indicator. Let's do them separately, combine and flag the actual retweets before we start doing analysis
